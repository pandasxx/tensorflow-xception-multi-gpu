# %%
from create_tfrecord import *
import os
% load_ext autoreload
% autoreload 2

# %%
src_path = "/home/nvme/train-data-xception/batch6.1-20181205-yuli/train"
dst_path = "/home/nvme/train-data-xception/batch6.1-20181205-yuli-h5py/train"
name = "cell_data_bigtest"

# %%
class_num = 20
class_label_dict = {"ACTINO" : 0,  "AGC_A"  : 1,  "AGC_B"  : 2,  "ASCUS"  : 3,  "CC"     : 4, 
                    "EC"     : 5,  "FUNGI"  : 6,  "GEC"    : 7,  "HSIL_B" : 8,  "HSIL_M" : 9,
                    "HSIL_S" : 10, "LSIL_E" : 11, "LSIL_F" : 12, "MC"     : 13, "RC"     : 14,
                    "SC"     : 15, "SCC_G"  : 16, "SCC_R"  : 17, "TRI"    : 18, "VIRUS"  : 19}


make_tfrecord_files(src_path, dst_path, name, class_label_dict, num_split = 10000)
# Out:
# make 0 file
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# make 1 file
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# make 2 file
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# make 3 file
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# make 4 file
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# make 5 file
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# make 6 file
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# make 7 file
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# make 8 file
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# make 9 file
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# make 10 file
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# make 11 file
# 1000
# 2000
# 3000
# 4000

# %%
src_path = "/home/nvme/train-data-xception/batch6.1-20181205-yuli/valid"
dst_path = "/home/nvme/train-data-xception/batch6.1-20181205-yuli-h5py/valid"
name = "cell_data_bigtest"

# %%
class_num = 20
class_label_dict = {"ACTINO" : 0,  "AGC_A"  : 1,  "AGC_B"  : 2,  "ASCUS"  : 3,  "CC"     : 4, 
                    "EC"     : 5,  "FUNGI"  : 6,  "GEC"    : 7,  "HSIL_B" : 8,  "HSIL_M" : 9,
                    "HSIL_S" : 10, "LSIL_E" : 11, "LSIL_F" : 12, "MC"     : 13, "RC"     : 14,
                    "SC"     : 15, "SCC_G"  : 16, "SCC_R"  : 17, "TRI"    : 18, "VIRUS"  : 19}


make_tfrecord_files(src_path, dst_path, name, class_label_dict, num_split = 10000)
# Out:
# make 0 file
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# make 1 file
# 1000
# 2000
