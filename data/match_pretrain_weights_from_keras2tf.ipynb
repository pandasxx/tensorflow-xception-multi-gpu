# %%
import h5py
import collections

# %%
def load_attributes_from_hdf5_group(group, name):
    if name in group.attrs:
        data = [n.decode('utf8') for n in group.attrs[name]]
    return data

# %%
# 1 open hdf5 file
# 2 get info
# 3 get layer names
# 4 get filtered_layer_names (which layer has weights)
# 5 get group by layer name
# 6 load layer's weight names from group by key 'weight_names'
# 7 load layer's weight value from group by weight names
# 8 fill all weights info into weights info dict

weight_dict = {}
weight_dict = collections.OrderedDict()

class WeightInfo():
    def __init__(self, name, shape, value):
        self.name = name
        self.shape = shape
        self.value = value
        

f = h5py.File('xception_weights_tf_dim_ordering_tf_kernels_notop.h5','r')
layer_names = load_attributes_from_hdf5_group(f, 'layer_names')

filtered_layer_names = []
for layer_name in layer_names:
    g = f[layer_name]
    weight_names = load_attributes_from_hdf5_group(g, 'weight_names')
    if weight_names:
        filtered_layer_names.append(layer_name)

layer_names = filtered_layer_names
for layer_name in layer_names:
    g = f[layer_name]
    weight_names = load_attributes_from_hdf5_group(g, 'weight_names')
    weight_values = [g[weight_name] for weight_name in weight_names]

    for i in range(len(weight_names)):
        weights_info = WeightInfo(name = weight_names[i], shape = weight_values[i].shape, value = weight_values[i][:])
        weight_dict[weight_names[i]] = weights_info

# %%
f.attrs['layer_names']
# Out:
# array([b'input_1', b'convolution2d_1', b'batchnormalization_1',
#        b'activation_1', b'convolution2d_2', b'batchnormalization_2',
#        b'activation_2', b'separableconvolution2d_1',
#        b'batchnormalization_4', b'activation_3',
#        b'separableconvolution2d_2', b'batchnormalization_5',
#        b'convolution2d_3', b'maxpooling2d_1', b'batchnormalization_3',
#        b'merge_1', b'activation_4', b'separableconvolution2d_3',
#        b'batchnormalization_7', b'activation_5',
#        b'separableconvolution2d_4', b'batchnormalization_8',
#        b'convolution2d_4', b'maxpooling2d_2', b'batchnormalization_6',
#        b'merge_2', b'activation_6', b'separableconvolution2d_5',
#        b'batchnormalization_10', b'activation_7',
#        b'separableconvolution2d_6', b'batchnormalization_11',
#        b'convolution2d_5', b'maxpooling2d_3', b'batchnormalization_9',
#        b'merge_3', b'activation_8', b'separableconvolution2d_7',
#        b'batchnormalization_12', b'activation_9',
#        b'separableconvolution2d_8', b'batchnormalization_13',
#        b'activation_10', b'separableconvolution2d_9',
#        b'batchnormalization_14', b'merge_4', b'activation_11',
#        b'separableconvolution2d_10', b'batchnormalization_15',
#        b'activation_12', b'separableconvolution2d_11',
#        b'batchnormalization_16', b'activation_13',
#        b'separableconvolution2d_12', b'batchnormalization_17', b'merge_5',
#        b'activation_14', b'separableconvolution2d_13',
#        b'batchnormalization_18', b'activation_15',
#        b'separableconvolution2d_14', b'batchnormalization_19',
#        b'activation_16', b'separableconvolution2d_15',
#        b'batchnormalization_20', b'merge_6', b'activation_17',
#        b'separableconvolution2d_16', b'batchnormalization_21',
#        b'activation_18', b'separableconvolution2d_17',
#        b'batchnormalization_22', b'activation_19',
#        b'separableconvolution2d_18', b'batchnormalization_23', b'merge_7',
#        b'activation_20', b'separableconvolution2d_19',
#        b'batchnormalization_24', b'activation_21',
#        b'separableconvolution2d_20', b'batchnormalization_25',
#        b'activation_22', b'separableconvolution2d_21',
#        b'batchnormalization_26', b'merge_8', b'activation_23',
#        b'separableconvolution2d_22', b'batchnormalization_27',
#        b'activation_24', b'separableconvolution2d_23',
#        b'batchnormalization_28', b'activation_25',
#        b'separableconvolution2d_24', b'batchnormalization_29', b'merge_9',
#        b'activation_26', b'separableconvolution2d_25',
#        b'batchnormalization_30', b'activation_27',
#        b'separableconvolution2d_26', b'batchnormalization_31',
#        b'activation_28', b'separableconvolution2d_27',
#        b'batchnormalization_32', b'merge_10', b'activation_29',
#        b'separableconvolution2d_28', b'batchnormalization_33',
#        b'activation_30', b'separableconvolution2d_29',
#        b'batchnormalization_34', b'activation_31',
#        b'separableconvolution2d_30', b'batchnormalization_35',
#        b'merge_11', b'activation_32', b'separableconvolution2d_31',
#        b'batchnormalization_37', b'activation_33',
#        b'separableconvolution2d_32', b'batchnormalization_38',
#        b'convolution2d_6', b'maxpooling2d_4', b'batchnormalization_36',
#        b'merge_12', b'separableconvolution2d_33',
#        b'batchnormalization_39', b'activation_34',
#        b'separableconvolution2d_34', b'batchnormalization_40',
#        b'activation_35'], dtype='|S25')

# %%
# 1 get all keys ()
# 2 get weight_names according key
# 3 

for key in f.keys():
    print("   ", key)
    weight_names = f[key].attrs['weight_names']
    if len(weight_names) == 0:
        print("    ###")
        print("   ", "no weights")
        print("    ###")
    else:
        print("    ###")
        print("   ", weight_names)
        print("    ###")
        
        print("    ***")
        weight_name = weight_names[0].decode('utf8')
        weight_value = f[key][weight_name]
        print("   ", weight_value[:])
        print("    ***")

        break
# Out:
#     add_13
#     ###
#     no weights
#     ###
#     add_14
#     ###
#     no weights
#     ###
#     add_15
#     ###
#     no weights
#     ###
#     add_16
#     ###
#     no weights
#     ###
#     add_17
#     ###
#     no weights
#     ###
#     add_18
#     ###
#     no weights
#     ###
#     add_19
#     ###
#     no weights
#     ###
#     add_20
#     ###
#     no weights
#     ###
#     add_21
#     ###
#     no weights
#     ###
#     add_22
#     ###
#     no weights
#     ###
#     add_23
#     ###
#     no weights
#     ###
#     add_24
#     ###
#     no weights
#     ###
#     batch_normalization_5
#     ###
#     [b'batch_normalization_5/gamma:0' b'batch_normalization_5/beta:0'
#  b'batch_normalization_5/moving_mean:0'
#  b'batch_normalization_5/moving_variance:0']
#     ###
#     ***
#     [1.3301327  0.79569155 0.55094653 0.6419058  0.6427124  0.71002626
#  0.55329    1.3230695  0.6779367  0.6930915  0.65078944 1.116016
#  1.4444473  1.5879644  0.8300074  0.88349485 0.5573512  0.6506222
#  0.7792169  0.80750805 0.72163194 1.3285041  1.1031047  1.1489141
#  1.021656   0.8350019  0.83043885 1.1317171  0.6592616  0.7289964
#  0.71016407 0.85775924 0.7849033  1.2222477  0.7258588  0.9546239
#  0.6393361  0.6235597  1.1957289  0.7232887  0.9263803  0.67284906
#  0.64802015 1.0251615  0.62021834 0.8424011  0.88361466 1.3644503
#  0.7500519  0.604401   1.1625965  0.8186589  1.5125251  0.90659773
#  0.73784167 0.98489106 0.6056016  0.73755515 0.6588278  1.2916379
#  0.826444   1.1718677  0.6329884  0.64852804 0.48196697 0.84902066
#  0.54425883 1.1373246  0.7908548  0.78073305 0.7201969  0.6321801
#  0.55833626 0.6669532  0.7735385  0.55851936 0.6425586  0.9021207
#  0.77925545 1.0462601  0.7798533  0.85979897 0.9130473  1.5355879
#  0.77044326 0.9032667  0.64128107 0.8584035  0.8690093  0.55989
#  0.7992442  0.77878606 0.8551688  1.0210034  0.64074874 0.9538094
#  0.8524581  0.879344   0.7618364  0.6552744  0.73648137 0.8632664
#  0.8468919  1.6927835  0.88463855 1.0949033  0.6980935  0.8442827
#  1.1732615  1.3568925  0.8904441  1.04297    0.8748823  0.80324084
#  0.7287969  0.9652271  0.91517365 0.83876127 1.4418498  0.5104699
#  0.85104334 1.1287217  0.7964871  0.8648333  0.6886786  0.9595575
#  0.8633726  0.7332718 ]
#     ***

# %%
print("   ", weight_value.shape)
weight_value[127]
# Out:
#     (128,)
# 0.7332718

# %%
print("   ", f['block10_sepconv1'].attrs.keys)
# Out:
#     <bound method MappingHDF5.keys of <Attributes of HDF5 object at 140689705655288>>

# %%
for key in f['block10_sepconv1'].attrs['weight_names']:
    print(key)
# Out:
# b'block10_sepconv1_1/depthwise_kernel:0'
# b'block10_sepconv1_1/pointwise_kernel:0'

# %%
for key in weight_dict.keys():
    print("   ##  ##")
    print("   ", weight_dict[key].name)
    print("   ", weight_dict[key].shape)
    print("   ", weight_dict[key].value.shape)
    print("   ##  ##")
# Out:
#    ##  ##
#     convolution2d_1_W:0
#     (3, 3, 3, 32)
#     (3, 3, 3, 32)
#    ##  ##
#    ##  ##
#     batchnormalization_1_gamma:0
#     (32,)
#     (32,)
#    ##  ##
#    ##  ##
#     batchnormalization_1_beta:0
#     (32,)
#     (32,)
#    ##  ##
#    ##  ##
#     batchnormalization_1_running_mean:0
#     (32,)
#     (32,)
#    ##  ##
#    ##  ##
#     batchnormalization_1_running_std:0
#     (32,)
#     (32,)
#    ##  ##
#    ##  ##
#     convolution2d_2_W:0
#     (3, 3, 32, 64)
#     (3, 3, 32, 64)
#    ##  ##
#    ##  ##
#     batchnormalization_2_gamma:0
#     (64,)
#     (64,)
#    ##  ##
#    ##  ##
#     batchnormalization_2_beta:0
#     (64,)
#     (64,)
#    ##  ##
#    ##  ##
#     batchnormalization_2_running_mean:0
#     (64,)
#     (64,)
#    ##  ##
#    ##  ##
#     batchnormalization_2_running_std:0
#     (64,)
#     (64,)
#    ##  ##
#    ##  ##
#     separableconvolution2d_1_depthwise_kernel:0
#     (3, 3, 64, 1)
#     (3, 3, 64, 1)
#    ##  ##
#    ##  ##
#     separableconvolution2d_1_pointwise_kernel:0
#     (1, 1, 64, 128)
#     (1, 1, 64, 128)
#    ##  ##
#    ##  ##
#     batchnormalization_4_gamma:0
#     (128,)
#     (128,)
#    ##  ##
#    ##  ##
#     batchnormalization_4_beta:0
#     (128,)
#     (128,)
#    ##  ##
#    ##  ##
#     batchnormalization_4_running_mean:0
#     (128,)
#     (128,)
#    ##  ##
#    ##  ##
#     batchnormalization_4_running_std:0
#     (128,)
#     (128,)
#    ##  ##
#    ##  ##
#     separableconvolution2d_2_depthwise_kernel:0
#     (3, 3, 128, 1)
#     (3, 3, 128, 1)
#    ##  ##
#    ##  ##
#     separableconvolution2d_2_pointwise_kernel:0
#     (1, 1, 128, 128)
#     (1, 1, 128, 128)
#    ##  ##
#    ##  ##
#     batchnormalization_5_gamma:0
#     (128,)
#     (128,)
#    ##  ##
#    ##  ##
#     batchnormalization_5_beta:0
#     (128,)
#     (128,)
#    ##  ##
#    ##  ##
#     batchnormalization_5_running_mean:0
#     (128,)
#     (128,)
#    ##  ##
#    ##  ##
#     batchnormalization_5_running_std:0
#     (128,)
#     (128,)
#    ##  ##
#    ##  ##
#     convolution2d_3_W:0
#     (1, 1, 64, 128)
#     (1, 1, 64, 128)
#    ##  ##
#    ##  ##
#     batchnormalization_3_gamma:0
#     (128,)
#     (128,)
#    ##  ##
#    ##  ##
#     batchnormalization_3_beta:0
#     (128,)
#     (128,)
#    ##  ##
#    ##  ##
#     batchnormalization_3_running_mean:0
#     (128,)
#     (128,)
#    ##  ##
#    ##  ##
#     batchnormalization_3_running_std:0
#     (128,)
#     (128,)
#    ##  ##
#    ##  ##
#     separableconvolution2d_3_depthwise_kernel:0
#     (3, 3, 128, 1)
#     (3, 3, 128, 1)
#    ##  ##
#    ##  ##
#     separableconvolution2d_3_pointwise_kernel:0
#     (1, 1, 128, 256)
#     (1, 1, 128, 256)
#    ##  ##
#    ##  ##
#     batchnormalization_7_gamma:0
#     (256,)
#     (256,)
#    ##  ##
#    ##  ##
#     batchnormalization_7_beta:0
#     (256,)
#     (256,)
#    ##  ##
#    ##  ##
#     batchnormalization_7_running_mean:0
#     (256,)
#     (256,)
#    ##  ##
#    ##  ##
#     batchnormalization_7_running_std:0
#     (256,)
#     (256,)
#    ##  ##
#    ##  ##
#     separableconvolution2d_4_depthwise_kernel:0
#     (3, 3, 256, 1)
#     (3, 3, 256, 1)
#    ##  ##
#    ##  ##
#     separableconvolution2d_4_pointwise_kernel:0
#     (1, 1, 256, 256)
#     (1, 1, 256, 256)
#    ##  ##
#    ##  ##
#     batchnormalization_8_gamma:0
#     (256,)
#     (256,)
#    ##  ##
#    ##  ##
#     batchnormalization_8_beta:0
#     (256,)
#     (256,)
#    ##  ##
#    ##  ##
#     batchnormalization_8_running_mean:0
#     (256,)
#     (256,)
#    ##  ##
#    ##  ##
#     batchnormalization_8_running_std:0
#     (256,)
#     (256,)
#    ##  ##
#    ##  ##
#     convolution2d_4_W:0
#     (1, 1, 128, 256)
#     (1, 1, 128, 256)
#    ##  ##
#    ##  ##
#     batchnormalization_6_gamma:0
#     (256,)
#     (256,)
#    ##  ##
#    ##  ##
#     batchnormalization_6_beta:0
#     (256,)
#     (256,)
#    ##  ##
#    ##  ##
#     batchnormalization_6_running_mean:0
#     (256,)
#     (256,)
#    ##  ##
#    ##  ##
#     batchnormalization_6_running_std:0
#     (256,)
#     (256,)
#    ##  ##
#    ##  ##
#     separableconvolution2d_5_depthwise_kernel:0
#     (3, 3, 256, 1)
#     (3, 3, 256, 1)
#    ##  ##
#    ##  ##
#     separableconvolution2d_5_pointwise_kernel:0
#     (1, 1, 256, 728)
#     (1, 1, 256, 728)
#    ##  ##
#    ##  ##
#     batchnormalization_10_gamma:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_10_beta:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_10_running_mean:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_10_running_std:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     separableconvolution2d_6_depthwise_kernel:0
#     (3, 3, 728, 1)
#     (3, 3, 728, 1)
#    ##  ##
#    ##  ##
#     separableconvolution2d_6_pointwise_kernel:0
#     (1, 1, 728, 728)
#     (1, 1, 728, 728)
#    ##  ##
#    ##  ##
#     batchnormalization_11_gamma:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_11_beta:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_11_running_mean:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_11_running_std:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     convolution2d_5_W:0
#     (1, 1, 256, 728)
#     (1, 1, 256, 728)
#    ##  ##
#    ##  ##
#     batchnormalization_9_gamma:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_9_beta:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_9_running_mean:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_9_running_std:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     separableconvolution2d_7_depthwise_kernel:0
#     (3, 3, 728, 1)
#     (3, 3, 728, 1)
#    ##  ##
#    ##  ##
#     separableconvolution2d_7_pointwise_kernel:0
#     (1, 1, 728, 728)
#     (1, 1, 728, 728)
#    ##  ##
#    ##  ##
#     batchnormalization_12_gamma:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_12_beta:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_12_running_mean:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_12_running_std:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     separableconvolution2d_8_depthwise_kernel:0
#     (3, 3, 728, 1)
#     (3, 3, 728, 1)
#    ##  ##
#    ##  ##
#     separableconvolution2d_8_pointwise_kernel:0
#     (1, 1, 728, 728)
#     (1, 1, 728, 728)
#    ##  ##
#    ##  ##
#     batchnormalization_13_gamma:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_13_beta:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_13_running_mean:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_13_running_std:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     separableconvolution2d_9_depthwise_kernel:0
#     (3, 3, 728, 1)
#     (3, 3, 728, 1)
#    ##  ##
#    ##  ##
#     separableconvolution2d_9_pointwise_kernel:0
#     (1, 1, 728, 728)
#     (1, 1, 728, 728)
#    ##  ##
#    ##  ##
#     batchnormalization_14_gamma:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_14_beta:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_14_running_mean:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_14_running_std:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     separableconvolution2d_10_depthwise_kernel:0
#     (3, 3, 728, 1)
#     (3, 3, 728, 1)
#    ##  ##
#    ##  ##
#     separableconvolution2d_10_pointwise_kernel:0
#     (1, 1, 728, 728)
#     (1, 1, 728, 728)
#    ##  ##
#    ##  ##
#     batchnormalization_15_gamma:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_15_beta:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_15_running_mean:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_15_running_std:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     separableconvolution2d_11_depthwise_kernel:0
#     (3, 3, 728, 1)
#     (3, 3, 728, 1)
#    ##  ##
#    ##  ##
#     separableconvolution2d_11_pointwise_kernel:0
#     (1, 1, 728, 728)
#     (1, 1, 728, 728)
#    ##  ##
#    ##  ##
#     batchnormalization_16_gamma:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_16_beta:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_16_running_mean:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_16_running_std:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     separableconvolution2d_12_depthwise_kernel:0
#     (3, 3, 728, 1)
#     (3, 3, 728, 1)
#    ##  ##
#    ##  ##
#     separableconvolution2d_12_pointwise_kernel:0
#     (1, 1, 728, 728)
#     (1, 1, 728, 728)
#    ##  ##
#    ##  ##
#     batchnormalization_17_gamma:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_17_beta:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_17_running_mean:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_17_running_std:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     separableconvolution2d_13_depthwise_kernel:0
#     (3, 3, 728, 1)
#     (3, 3, 728, 1)
#    ##  ##
#    ##  ##
#     separableconvolution2d_13_pointwise_kernel:0
#     (1, 1, 728, 728)
#     (1, 1, 728, 728)
#    ##  ##
#    ##  ##
#     batchnormalization_18_gamma:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_18_beta:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_18_running_mean:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_18_running_std:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     separableconvolution2d_14_depthwise_kernel:0
#     (3, 3, 728, 1)
#     (3, 3, 728, 1)
#    ##  ##
#    ##  ##
#     separableconvolution2d_14_pointwise_kernel:0
#     (1, 1, 728, 728)
#     (1, 1, 728, 728)
#    ##  ##
#    ##  ##
#     batchnormalization_19_gamma:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_19_beta:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_19_running_mean:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_19_running_std:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     separableconvolution2d_15_depthwise_kernel:0
#     (3, 3, 728, 1)
#     (3, 3, 728, 1)
#    ##  ##
#    ##  ##
#     separableconvolution2d_15_pointwise_kernel:0
#     (1, 1, 728, 728)
#     (1, 1, 728, 728)
#    ##  ##
#    ##  ##
#     batchnormalization_20_gamma:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_20_beta:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_20_running_mean:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_20_running_std:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     separableconvolution2d_16_depthwise_kernel:0
#     (3, 3, 728, 1)
#     (3, 3, 728, 1)
#    ##  ##
#    ##  ##
#     separableconvolution2d_16_pointwise_kernel:0
#     (1, 1, 728, 728)
#     (1, 1, 728, 728)
#    ##  ##
#    ##  ##
#     batchnormalization_21_gamma:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_21_beta:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_21_running_mean:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_21_running_std:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     separableconvolution2d_17_depthwise_kernel:0
#     (3, 3, 728, 1)
#     (3, 3, 728, 1)
#    ##  ##
#    ##  ##
#     separableconvolution2d_17_pointwise_kernel:0
#     (1, 1, 728, 728)
#     (1, 1, 728, 728)
#    ##  ##
#    ##  ##
#     batchnormalization_22_gamma:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_22_beta:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_22_running_mean:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_22_running_std:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     separableconvolution2d_18_depthwise_kernel:0
#     (3, 3, 728, 1)
#     (3, 3, 728, 1)
#    ##  ##
#    ##  ##
#     separableconvolution2d_18_pointwise_kernel:0
#     (1, 1, 728, 728)
#     (1, 1, 728, 728)
#    ##  ##
#    ##  ##
#     batchnormalization_23_gamma:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_23_beta:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_23_running_mean:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_23_running_std:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     separableconvolution2d_19_depthwise_kernel:0
#     (3, 3, 728, 1)
#     (3, 3, 728, 1)
#    ##  ##
#    ##  ##
#     separableconvolution2d_19_pointwise_kernel:0
#     (1, 1, 728, 728)
#     (1, 1, 728, 728)
#    ##  ##
#    ##  ##
#     batchnormalization_24_gamma:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_24_beta:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_24_running_mean:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_24_running_std:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     separableconvolution2d_20_depthwise_kernel:0
#     (3, 3, 728, 1)
#     (3, 3, 728, 1)
#    ##  ##
#    ##  ##
#     separableconvolution2d_20_pointwise_kernel:0
#     (1, 1, 728, 728)
#     (1, 1, 728, 728)
#    ##  ##
#    ##  ##
#     batchnormalization_25_gamma:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_25_beta:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_25_running_mean:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_25_running_std:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     separableconvolution2d_21_depthwise_kernel:0
#     (3, 3, 728, 1)
#     (3, 3, 728, 1)
#    ##  ##
#    ##  ##
#     separableconvolution2d_21_pointwise_kernel:0
#     (1, 1, 728, 728)
#     (1, 1, 728, 728)
#    ##  ##
#    ##  ##
#     batchnormalization_26_gamma:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_26_beta:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_26_running_mean:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_26_running_std:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     separableconvolution2d_22_depthwise_kernel:0
#     (3, 3, 728, 1)
#     (3, 3, 728, 1)
#    ##  ##
#    ##  ##
#     separableconvolution2d_22_pointwise_kernel:0
#     (1, 1, 728, 728)
#     (1, 1, 728, 728)
#    ##  ##
#    ##  ##
#     batchnormalization_27_gamma:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_27_beta:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_27_running_mean:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_27_running_std:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     separableconvolution2d_23_depthwise_kernel:0
#     (3, 3, 728, 1)
#     (3, 3, 728, 1)
#    ##  ##
#    ##  ##
#     separableconvolution2d_23_pointwise_kernel:0
#     (1, 1, 728, 728)
#     (1, 1, 728, 728)
#    ##  ##
#    ##  ##
#     batchnormalization_28_gamma:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_28_beta:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_28_running_mean:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_28_running_std:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     separableconvolution2d_24_depthwise_kernel:0
#     (3, 3, 728, 1)
#     (3, 3, 728, 1)
#    ##  ##
#    ##  ##
#     separableconvolution2d_24_pointwise_kernel:0
#     (1, 1, 728, 728)
#     (1, 1, 728, 728)
#    ##  ##
#    ##  ##
#     batchnormalization_29_gamma:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_29_beta:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_29_running_mean:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_29_running_std:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     separableconvolution2d_25_depthwise_kernel:0
#     (3, 3, 728, 1)
#     (3, 3, 728, 1)
#    ##  ##
#    ##  ##
#     separableconvolution2d_25_pointwise_kernel:0
#     (1, 1, 728, 728)
#     (1, 1, 728, 728)
#    ##  ##
#    ##  ##
#     batchnormalization_30_gamma:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_30_beta:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_30_running_mean:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_30_running_std:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     separableconvolution2d_26_depthwise_kernel:0
#     (3, 3, 728, 1)
#     (3, 3, 728, 1)
#    ##  ##
#    ##  ##
#     separableconvolution2d_26_pointwise_kernel:0
#     (1, 1, 728, 728)
#     (1, 1, 728, 728)
#    ##  ##
#    ##  ##
#     batchnormalization_31_gamma:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_31_beta:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_31_running_mean:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_31_running_std:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     separableconvolution2d_27_depthwise_kernel:0
#     (3, 3, 728, 1)
#     (3, 3, 728, 1)
#    ##  ##
#    ##  ##
#     separableconvolution2d_27_pointwise_kernel:0
#     (1, 1, 728, 728)
#     (1, 1, 728, 728)
#    ##  ##
#    ##  ##
#     batchnormalization_32_gamma:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_32_beta:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_32_running_mean:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_32_running_std:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     separableconvolution2d_28_depthwise_kernel:0
#     (3, 3, 728, 1)
#     (3, 3, 728, 1)
#    ##  ##
#    ##  ##
#     separableconvolution2d_28_pointwise_kernel:0
#     (1, 1, 728, 728)
#     (1, 1, 728, 728)
#    ##  ##
#    ##  ##
#     batchnormalization_33_gamma:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_33_beta:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_33_running_mean:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_33_running_std:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     separableconvolution2d_29_depthwise_kernel:0
#     (3, 3, 728, 1)
#     (3, 3, 728, 1)
#    ##  ##
#    ##  ##
#     separableconvolution2d_29_pointwise_kernel:0
#     (1, 1, 728, 728)
#     (1, 1, 728, 728)
#    ##  ##
#    ##  ##
#     batchnormalization_34_gamma:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_34_beta:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_34_running_mean:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_34_running_std:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     separableconvolution2d_30_depthwise_kernel:0
#     (3, 3, 728, 1)
#     (3, 3, 728, 1)
#    ##  ##
#    ##  ##
#     separableconvolution2d_30_pointwise_kernel:0
#     (1, 1, 728, 728)
#     (1, 1, 728, 728)
#    ##  ##
#    ##  ##
#     batchnormalization_35_gamma:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_35_beta:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_35_running_mean:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_35_running_std:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     separableconvolution2d_31_depthwise_kernel:0
#     (3, 3, 728, 1)
#     (3, 3, 728, 1)
#    ##  ##
#    ##  ##
#     separableconvolution2d_31_pointwise_kernel:0
#     (1, 1, 728, 728)
#     (1, 1, 728, 728)
#    ##  ##
#    ##  ##
#     batchnormalization_37_gamma:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_37_beta:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_37_running_mean:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     batchnormalization_37_running_std:0
#     (728,)
#     (728,)
#    ##  ##
#    ##  ##
#     separableconvolution2d_32_depthwise_kernel:0
#     (3, 3, 728, 1)
#     (3, 3, 728, 1)
#    ##  ##
#    ##  ##
#     separableconvolution2d_32_pointwise_kernel:0
#     (1, 1, 728, 1024)
#     (1, 1, 728, 1024)
#    ##  ##
#    ##  ##
#     batchnormalization_38_gamma:0
#     (1024,)
#     (1024,)
#    ##  ##
#    ##  ##
#     batchnormalization_38_beta:0
#     (1024,)
#     (1024,)
#    ##  ##
#    ##  ##
#     batchnormalization_38_running_mean:0
#     (1024,)
#     (1024,)
#    ##  ##
#    ##  ##
#     batchnormalization_38_running_std:0
#     (1024,)
#     (1024,)
#    ##  ##
#    ##  ##
#     convolution2d_6_W:0
#     (1, 1, 728, 1024)
#     (1, 1, 728, 1024)
#    ##  ##
#    ##  ##
#     batchnormalization_36_gamma:0
#     (1024,)
#     (1024,)
#    ##  ##
#    ##  ##
#     batchnormalization_36_beta:0
#     (1024,)
#     (1024,)
#    ##  ##
#    ##  ##
#     batchnormalization_36_running_mean:0
#     (1024,)
#     (1024,)
#    ##  ##
#    ##  ##
#     batchnormalization_36_running_std:0
#     (1024,)
#     (1024,)
#    ##  ##
#    ##  ##
#     separableconvolution2d_33_depthwise_kernel:0
#     (3, 3, 1024, 1)
#     (3, 3, 1024, 1)
#    ##  ##
#    ##  ##
#     separableconvolution2d_33_pointwise_kernel:0
#     (1, 1, 1024, 1536)
#     (1, 1, 1024, 1536)
#    ##  ##
#    ##  ##
#     batchnormalization_39_gamma:0
#     (1536,)
#     (1536,)
#    ##  ##
#    ##  ##
#     batchnormalization_39_beta:0
#     (1536,)
#     (1536,)
#    ##  ##
#    ##  ##
#     batchnormalization_39_running_mean:0
#     (1536,)
#     (1536,)
#    ##  ##
#    ##  ##
#     batchnormalization_39_running_std:0
#     (1536,)
#     (1536,)
#    ##  ##
#    ##  ##
#     separableconvolution2d_34_depthwise_kernel:0
#     (3, 3, 1536, 1)
#     (3, 3, 1536, 1)
#    ##  ##
#    ##  ##
#     separableconvolution2d_34_pointwise_kernel:0
#     (1, 1, 1536, 2048)
#     (1, 1, 1536, 2048)
#    ##  ##
#    ##  ##
#     batchnormalization_40_gamma:0
#     (2048,)
#     (2048,)
#    ##  ##
#    ##  ##
#     batchnormalization_40_beta:0
#     (2048,)
#     (2048,)
#    ##  ##
#    ##  ##
#     batchnormalization_40_running_mean:0
#     (2048,)
#     (2048,)
#    ##  ##
#    ##  ##
#     batchnormalization_40_running_std:0
#     (2048,)
#     (2048,)
#    ##  ##
